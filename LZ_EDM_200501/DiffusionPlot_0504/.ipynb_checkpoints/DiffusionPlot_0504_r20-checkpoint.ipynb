# %%
#Visualise drift lines

# %%
#INITIALIZION
#Kernel PyROOT
import os
#os.sys.path.append('/usr/common/software/rootpy')
#os.sys.path.insert(0,'/usr/common/software/uproot')
#import root_numpy
#import root_numpy as root_np
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.use('GTK3Agg')
import ROOT
import pandas as pd
from scipy.optimize import curve_fit

import sys
from matplotlib.colors import LogNorm
import pylab

import glob
import uproot

import scipy
from scipy.optimize import curve_fit

# %pylab inline
#pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

print("Starting notebook....")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Starting notebook....

# %%
#Function to turn file into arrays


def Get_R_Z_DT_arrays(filename):
    file = open(filename, 'r')
    lines = file.readlines()

    #print len(lines)
    #print lines[2]

    rIN_cm = float(lines[10].split('\t\t')[0])
    zIN_cm = float(lines[10].split('\t\t')[1])

    DriftTime_us_list = []
    r_cm_list = []
    z_cm_list = []

    DriftTime_us_list.append(0.0)
    r_cm_list.append(rIN_cm)
    z_cm_list.append(zIN_cm)

    for i in range(0,len(lines)):
        if lines[i].startswith('#'):
            continue
        else:
            a = lines[i].split('\t\t')
            #print a
            DriftTime_us_list.append(float(a[2]))
            r_cm_list.append(float(a[3]))
            z_cm_list.append(float(a[4]))
    return np.asarray(r_cm_list), np.asarray(z_cm_list), np.asarray(DriftTime_us_list)

print "\n\t...Done!"
# Out:
# 	...Done!

# %%
#Get all txt files in directory
file_list=[]
for file in os.listdir("."):
    if file.endswith(".txt"):
        print(os.path.join(file))
        file_list.append(os.path.join(file))
# Out:
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_1.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_2.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_3.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_4.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_5.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_6.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_7.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_8.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_9.txt
# SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504.txt
# SingleDriftLineCalc_.05cm_r20cm_z0.5cm_0504.txt

# %%
#This should work ... why isn't it?
figure(1)
for i in range(0, len(file_list)):
    r_cm_array, z_cm_array, DriftTime_us_array = Get_R_Z_DT_arrays(file_list[i])
    #print file_list[i]
    #print Diff_z_cm_array[-1]
    
    if file_list[i].startswith('SingleDriftLineCalc'):
        plt.plot(r_cm_array[:pop], z_cm_array[:pop], '-k', linewidth=3, label='Drift line')
    else:
        plt.plot(r_cm_array, z_cm_array, '-', label='Diffusion line')
        
        
plt.xlabel('R [cm]',fontsize=18,family='serif')
plt.ylabel('Z [cm]',fontsize=18,family='serif')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
pylab.legend(loc='best', fontsize=12)

plt.ylim(0.95, 145)
plt.xlim(19.2,20.5)
# Out:
# (19.2, 20.5)

# %%
filename = "SingleDriftLineCalc_.05cm_r20cm_z0.5cm_0504.txt"
Drift_r_cm_array, Drift_z_cm_array, Drift_DriftTime_us_array = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504.txt"
Diff_r_cm_array, Diff_z_cm_array, Diff_DriftTime_us_array = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_1.txt"
Diff_r_cm_array_1, Diff_z_cm_array_1, Diff_DriftTime_us_array_1 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_2.txt"
Diff_r_cm_array_2, Diff_z_cm_array_2, Diff_DriftTime_us_array_2 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_3.txt"
Diff_r_cm_array_3, Diff_z_cm_array_3, Diff_DriftTime_us_array_3 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_4.txt"
Diff_r_cm_array_4, Diff_z_cm_array_4, Diff_DriftTime_us_array_4 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_5.txt"
Diff_r_cm_array_5, Diff_z_cm_array_5, Diff_DriftTime_us_array_5 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_6.txt"
Diff_r_cm_array_6, Diff_z_cm_array_6, Diff_DriftTime_us_array_6 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_7.txt"
Diff_r_cm_array_7, Diff_z_cm_array_7, Diff_DriftTime_us_array_7 = Get_R_Z_DT_arrays(filename)

filename = "SingleDiffusionLineMC_TimeStep_.32us_r20cm_z0.5cm_0504_8.txt"
Diff_r_cm_array_8, Diff_z_cm_array_8, Diff_DriftTime_us_array_8 = Get_R_Z_DT_arrays(filename)



#filename = "SingleDriftLineCalc_TimeStep_1us_r20cm_z01.5cm_0504.txt"
#r_cm_array, z_cm_array, DriftTime_us_array = Get_R_Z_DT_arrays(filename)

print "\n\t...Done!"
# Out:
# 	...Done!

# %%
#quick plot
pop=-14

figure(1)
plt.plot(Drift_r_cm_array[:pop], Drift_z_cm_array[:pop], '-k', label='Drift line')
plt.plot(Diff_r_cm_array, Diff_z_cm_array, '-r', label='Diffusion line')
plt.plot(Diff_r_cm_array_1, Diff_z_cm_array_1, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_2, Diff_z_cm_array_2, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_3, Diff_z_cm_array_3, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_4, Diff_z_cm_array_4, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_5, Diff_z_cm_array_5, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_6, Diff_z_cm_array_6, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_7, Diff_z_cm_array_7, '-', label='Diffusion line')
plt.plot(Diff_r_cm_array_8, Diff_z_cm_array_8, '-', label='Diffusion line')




plt.xlabel('R [cm]',fontsize=18,family='serif')
plt.ylabel('Z [cm]',fontsize=18,family='serif')



plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
pylab.legend(loc='upper right', fontsize=12)



plt.ylim(0.95, 145)
plt.xlim(19,20.5)
# Out:
# (19, 20.5)

# %%
#Try averaging together 10 diffusion lines
